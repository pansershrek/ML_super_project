# %%
import numpy as np
import pandas as pd
import re

# %%
data_features = pd.read_csv("condition_csi/dataset/train/subs_features_train.csv",sep=";")
data_features.head()
# Out:
#   SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 0  01.08.01          4   3339         80          5          2    1
# 1  01.08.01          4    238         75          5          2    1
# 2  01.08.01          4   4669         43          5          2    1
# 3  01.08.01          4   2555         54          5          2    1
# 4  01.08.01          4   2291         38          5          2    1
#
#    ARPU_GROUP  COM_CAT#7  COM_CAT#8    ...      COM_CAT#25  COM_CAT#26  \
# 0        12.0          1     1489.0    ...               1           1
# 1         7.0          1      945.0    ...               1           1
# 2         3.0          3     1033.0    ...               1           1
# 3        12.0          1      512.0    ...               1           1
# 4         7.0          1     1268.0    ...               1           1
#
#   COM_CAT#27 COM_CAT#28 COM_CAT#29 COM_CAT#30 COM_CAT#31 COM_CAT#32  \
# ...

# %%
def to_f(x):
    if issubclass(str,type(x)):
        x = x.replace(',','.')
    return float(x)
to_float = np.vectorize(to_f)

# %%
CAT = []
for i in data_features.columns:
    if re.match(r'COM_CAT',i) or re.match(r'REVENUE',i) or re.match(r'ITC',i) or re.match(r'VAS',i) or re.match(r'RENT_CHANNEL',i) or re.match(r'ROAM',i) or re.match(r'COST',i):
        CAT.append(i)

# %%
for i in CAT:
    data_features[i] = to_float(data_features[i])

# %%
data_features.head()
# Out:
#   SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 0  01.08.01        4.0   3339       80.0        5.0          2    1
# 1  01.08.01        4.0    238       75.0        5.0          2    1
# 2  01.08.01        4.0   4669       43.0        5.0          2    1
# 3  01.08.01        4.0   2555       54.0        5.0          2    1
# 4  01.08.01        4.0   2291       38.0        5.0          2    1
#
#    ARPU_GROUP  COM_CAT#7  COM_CAT#8     ...      COM_CAT#25  COM_CAT#26  \
# 0        12.0        1.0     1489.0     ...             1.0         1.0
# 1         7.0        1.0      945.0     ...             1.0         1.0
# 2         3.0        3.0     1033.0     ...             1.0         1.0
# 3        12.0        1.0      512.0     ...             1.0         1.0
# 4         7.0        1.0     1268.0     ...             1.0         1.0
#
#    COM_CAT#27  COM_CAT#28  COM_CAT#29  COM_CAT#30  COM_CAT#31  COM_CAT#32  \
# ...

# %%
data_labels = pd.read_csv("condition_csi/dataset/train/subs_csi_train.csv", sep = ';')

# %%
data_labels.head()
# Out:
#    SK_ID  CSI  CONTACT_DATE
# 0      2    0          4.05
# 1      3    0         21.05
# 2      4    0         27.05
# 3      5    0          8.05
# 4      6    1          6.05

# %%
d = pd.merge(data_labels,data_features,on='SK_ID',how='left')

# %%
d
# Out:
#        SK_ID  CSI  CONTACT_DATE SNAP_DATE  COM_CAT#1  COM_CAT#2  COM_CAT#3  \
# 0          2    0          4.05  01.03.02        7.0       77.0       10.0
# 1          2    0          4.05  01.02.02        7.0       77.0        9.0
# 2          2    0          4.05  01.05.02        7.0       77.0       12.0
# 3          2    0          4.05  01.01.02        7.0       77.0       17.0
# 4          2    0          4.05  01.04.02        7.0       77.0       11.0
# 5          3    0         21.05  01.01.02        4.0       51.0       12.0
# 6          3    0         21.05  01.12.01        4.0       51.0       11.0
# 7          3    0         21.05  01.10.01        4.0       51.0        9.0
# 8          3    0         21.05  01.09.01        4.0       51.0       17.0
# 9          3    0         21.05  01.02.02        4.0       51.0       13.0
# 10         3    0         21.05  01.11.01        4.0       51.0       10.0
# ...

# %%
np.shape(d)
# Out:
# (47411, 38)

# %%
d.isnull().sum()
# Out:
# SK_ID                  0
# CSI                    0
# CONTACT_DATE           0
# SNAP_DATE              0
# COM_CAT#1              0
# COM_CAT#2              0
# COM_CAT#3              0
# BASE_TYPE              0
# ACT                    0
# ARPU_GROUP            21
# COM_CAT#7              0
# COM_CAT#8            124
# DEVICE_TYPE_ID       111
# INTERNET_TYPE_ID     111
# REVENUE                0
# ITC                    0
# VAS                    0
# RENT_CHANNEL           0
# ROAM                   0
# COST                   0
# COM_CAT#17             0
# COM_CAT#18             0
# COM_CAT#19             0
# COM_CAT#20             0
# COM_CAT#21             0
# COM_CAT#22             0
# COM_CAT#23             0
# COM_CAT#24             0
# COM_CAT#25             0
# COM_CAT#26             0
# COM_CAT#27             0
# COM_CAT#28             0
# COM_CAT#29             0
# COM_CAT#30             0
# COM_CAT#31             0
# COM_CAT#32             0
# COM_CAT#33             0
# ...

# %%
d.fillna(value=-1.0)
# Out:
#        SK_ID  CSI  CONTACT_DATE SNAP_DATE  COM_CAT#1  COM_CAT#2  COM_CAT#3  \
# 0          2    0          4.05  01.03.02        7.0       77.0       10.0
# 1          2    0          4.05  01.02.02        7.0       77.0        9.0
# 2          2    0          4.05  01.05.02        7.0       77.0       12.0
# 3          2    0          4.05  01.01.02        7.0       77.0       17.0
# 4          2    0          4.05  01.04.02        7.0       77.0       11.0
# 5          3    0         21.05  01.01.02        4.0       51.0       12.0
# 6          3    0         21.05  01.12.01        4.0       51.0       11.0
# 7          3    0         21.05  01.10.01        4.0       51.0        9.0
# 8          3    0         21.05  01.09.01        4.0       51.0       17.0
# 9          3    0         21.05  01.02.02        4.0       51.0       13.0
# 10         3    0         21.05  01.11.01        4.0       51.0       10.0
# ...

# %%
X = d.drop("CSI", axis=1)
y = d.CSI

# %%
X.head()
# Out:
#    SK_ID  CONTACT_DATE SNAP_DATE  COM_CAT#1  COM_CAT#2  COM_CAT#3  BASE_TYPE  \
# 0      2          4.05  01.03.02        7.0       77.0       10.0          1
# 1      2          4.05  01.02.02        7.0       77.0        9.0          1
# 2      2          4.05  01.05.02        7.0       77.0       12.0          1
# 3      2          4.05  01.01.02        7.0       77.0       17.0          1
# 4      2          4.05  01.04.02        7.0       77.0       11.0          1
#
#    ACT  ARPU_GROUP  COM_CAT#7     ...      COM_CAT#25  COM_CAT#26  COM_CAT#27  \
# 0    1        10.0        2.0     ...             1.0         1.0    0.002070
# 1    1        10.0        2.0     ...             1.0         1.0    0.003913
# 2    1         9.0        2.0     ...             1.0         1.0    0.001801
# 3    1         6.0        2.0     ...             1.0         0.0    0.001798
# 4    1         8.0        2.0     ...             1.0         1.0    0.006520
#
# ...

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: CSI, dtype: int64

# %%
np.shape(X)
# Out:
# (47411, 37)

# %%
data_features_test = pd.read_csv("condition_csi/dataset/test/subs_features_test.csv",sep=";")
for i in CAT:
    data_features_test[i] = to_float(data_features_test[i])
data_features_test.head()
# Out:
#   SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 0  01.10.01        8.0   6954       44.0       12.0          1    1
# 1  01.10.01        8.0   9663       44.0        5.0          2    1
# 2  01.10.01        8.0   7895       12.0        5.0          2    1
# 3  01.10.01        8.0   8913       52.0        8.0          2    1
# 4  01.10.01        8.0   8876       44.0        5.0          2    1
#
#    ARPU_GROUP  COM_CAT#7  COM_CAT#8     ...      COM_CAT#25  COM_CAT#26  \
# 0        12.0        3.0        NaN     ...             1.0         1.0
# 1         8.0        1.0      952.0     ...             1.0         1.0
# 2         7.0        4.0     1322.0     ...             1.0         1.0
# 3         9.0        1.0      126.0     ...             1.0         1.0
# 4         7.0        3.0     1244.0     ...             1.0         1.0
#
#    COM_CAT#27  COM_CAT#28  COM_CAT#29  COM_CAT#30  COM_CAT#31  COM_CAT#32  \
# ...

# %%
data_labels_test = pd.read_csv("condition_csi/dataset/test/subs_csi_test.csv", sep = ';')
data_labels_test.shape
# Out:
# (5221, 2)

# %%
d_test = pd.merge(data_labels_test,data_features_test,on='SK_ID',how='left')
d_test.head()
# Out:
#    SK_ID  CONTACT_DATE SNAP_DATE  COM_CAT#1  COM_CAT#2  COM_CAT#3  BASE_TYPE  \
# 0   6184          2.04  01.07.01        4.0       50.0        5.0          2
# 1   6184          2.04  01.10.01        4.0       50.0        5.0          2
# 2   6184          2.04  01.04.02        4.0       50.0        5.0          2
# 3   6184          2.04  01.12.01        4.0       50.0        5.0          2
# 4   6184          2.04  01.06.01        4.0       50.0        5.0          2
#
#    ACT  ARPU_GROUP  COM_CAT#7     ...      COM_CAT#25  COM_CAT#26  COM_CAT#27  \
# 0    1         6.0        4.0     ...             1.0         1.0    0.003549
# 1    1        11.0        2.0     ...             1.0         1.0    0.012225
# 2    1         8.0        2.0     ...             1.0         1.0    0.019367
# 3    1         6.0        2.0     ...             1.0         1.0    0.006810
# 4    1         2.0        4.0     ...             1.0         1.0    0.000667
#
# ...

# %%
d_test.shape
# Out:
# (58989, 37)

# %%
d_test.fillna(value=-1.0)
# Out:
#        SK_ID  CONTACT_DATE SNAP_DATE  COM_CAT#1  COM_CAT#2  COM_CAT#3  \
# 0       6184          2.04  01.07.01        4.0       50.0        5.0
# 1       6184          2.04  01.10.01        4.0       50.0        5.0
# 2       6184          2.04  01.04.02        4.0       50.0        5.0
# 3       6184          2.04  01.12.01        4.0       50.0        5.0
# 4       6184          2.04  01.06.01        4.0       50.0        5.0
# 5       6184          2.04  01.02.02        4.0       50.0        5.0
# 6       6184          2.04  01.09.01        4.0       50.0        5.0
# 7       6184          2.04  01.11.01        4.0       50.0        5.0
# 8       6184          2.04  01.03.02        4.0       50.0        5.0
# 9       6184          2.04  01.08.01        4.0       50.0        5.0
# 10      6184          2.04  01.01.02        4.0       50.0        5.0
# 11      6184          2.04  01.05.01        4.0       50.0        5.0
# ...

# %%
X_test = d_test

# %%
X.columns.values
# Out:
# array(['SK_ID', 'CONTACT_DATE', 'SNAP_DATE', 'COM_CAT#1', 'COM_CAT#2',
#        'COM_CAT#3', 'BASE_TYPE', 'ACT', 'ARPU_GROUP', 'COM_CAT#7',
#        'COM_CAT#8', 'DEVICE_TYPE_ID', 'INTERNET_TYPE_ID', 'REVENUE',
#        'ITC', 'VAS', 'RENT_CHANNEL', 'ROAM', 'COST', 'COM_CAT#17',
#        'COM_CAT#18', 'COM_CAT#19', 'COM_CAT#20', 'COM_CAT#21',
#        'COM_CAT#22', 'COM_CAT#23', 'COM_CAT#24', 'COM_CAT#25',
#        'COM_CAT#26', 'COM_CAT#27', 'COM_CAT#28', 'COM_CAT#29',
#        'COM_CAT#30', 'COM_CAT#31', 'COM_CAT#32', 'COM_CAT#33',
#        'COM_CAT#34'], dtype=object)

# %%
cols = list(set(X.columns.values) - set (['CONTACT_DATE','SNAP_DATE', 'COM_CAT#8', 'DEVICE_TYPE_ID', 'INTERNET_TYPE_ID', 'COM_CAT#34', 'ARPU_GROUP' ]))
np.shape(cols)
# Out:
# (30,)

# %%
cols
# Out:
# ['ACT',
#  'COM_CAT#31',
#  'COM_CAT#2',
#  'COM_CAT#25',
#  'ROAM',
#  'COM_CAT#29',
#  'SK_ID',
#  'COM_CAT#32',
#  'COM_CAT#24',
#  'COM_CAT#17',
#  'COM_CAT#19',
#  'COM_CAT#7',
#  'COM_CAT#18',
#  'COM_CAT#20',
#  'COM_CAT#27',
#  'COM_CAT#26',
#  'COM_CAT#30',
#  'COM_CAT#28',
#  'COM_CAT#22',
#  'COM_CAT#23',
#  'RENT_CHANNEL',
#  'VAS',
#  'COM_CAT#3',
#  'COST',
#  'COM_CAT#21',
#  'ITC',
#  'REVENUE',
#  'BASE_TYPE',
#  'COM_CAT#1',
#  'COM_CAT#33']

# %%
X.columns
# Out:
# Index(['SK_ID', 'CONTACT_DATE', 'SNAP_DATE', 'COM_CAT#1', 'COM_CAT#2',
#        'COM_CAT#3', 'BASE_TYPE', 'ACT', 'ARPU_GROUP', 'COM_CAT#7', 'COM_CAT#8',
#        'DEVICE_TYPE_ID', 'INTERNET_TYPE_ID', 'REVENUE', 'ITC', 'VAS',
#        'RENT_CHANNEL', 'ROAM', 'COST', 'COM_CAT#17', 'COM_CAT#18',
#        'COM_CAT#19', 'COM_CAT#20', 'COM_CAT#21', 'COM_CAT#22', 'COM_CAT#23',
#        'COM_CAT#24', 'COM_CAT#25', 'COM_CAT#26', 'COM_CAT#27', 'COM_CAT#28',
#        'COM_CAT#29', 'COM_CAT#30', 'COM_CAT#31', 'COM_CAT#32', 'COM_CAT#33',
#        'COM_CAT#34'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
X, Xt, y, yt = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score

clf = DecisionTreeClassifier(random_state=7)
for i in range(20):
    select_best_params = SelectKBest(k=30-i)
    X_cols = select_best_params.fit_transform(X[cols], y)
    #print(X_cols)
    indices = select_best_params.get_support()
    new_cols = []
    for i, elem in enumerate(indices):
        if not elem:
            print(cols[i])
        else:
            new_cols.append(cols[i])
    #print(new_cols)
    X_new = X[new_cols]
    X_new_test = X_test[new_cols]
    #print(X_new)
    #new_cols
    clf.fit(X_new, y)
    res = clf.predict(Xt[new_cols])
    print(roc_auc_score(res, yt))
# Out:
# 0.8299801992492171
# COM_CAT#19
# 0.8265458784011949
# ROAM
# COM_CAT#19
# 0.8257661063943872
# COM_CAT#25
# ROAM
# COM_CAT#19
# 0.8265697374378262
# COM_CAT#25
# ROAM
# COM_CAT#32
# COM_CAT#19
# 0.8246883340338061
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#19
# 0.6583771577512767
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#19
# COM_CAT#30
# 0.6609894925621972
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#19
# COM_CAT#18
# COM_CAT#30
# 0.6606780920334442
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#24
# COM_CAT#19
# COM_CAT#18
# COM_CAT#30
# 0.6639048915835455
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#24
# COM_CAT#19
# COM_CAT#18
# COM_CAT#30
# COM_CAT#3
# 0.6546638677631857
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#24
# COM_CAT#19
# COM_CAT#18
# COM_CAT#30
# VAS
# COM_CAT#3
# 0.650296473469287
# COM_CAT#25
# ROAM
# SK_ID
# COM_CAT#32
# COM_CAT#24
# COM_CAT#19
# COM_CAT#18
# COM_CAT#26
# COM_CAT#30
# VAS
# COM_CAT#3
# 0.6570112511974303
# ...

# %%
select_best_params = SelectKBest(k=29)
X_cols = select_best_params.fit_transform(X[cols], y)
#print(X_cols)
indices = select_best_params.get_support()
new_cols = []
for i, elem in enumerate(indices):
    if not elem:
        print(cols[i])
    else:
        new_cols.append(cols[i])
#print(new_cols)
X_new = X[new_cols]
X_new_test = X_test[new_cols]
#print(X_new)
#new_cols
clf.fit(X_new, y)
res = clf.predict(X_test[new_cols])
#print(roc_auc_score(res, yt))

ans = clf.predict(X_test[new_cols])
# Out:
# COM_CAT#19

# %%
c = pd.DataFrame(pred)

# %%
df = pd.DataFrame(ans)
dfd = X_test.copy()
dfd['RES'] = df
dfd['RES'].value_counts()
a = set()
with open("ans.csv","w") as file:
    for i in data_labels_test['SK_ID']:
        if ((dfd[dfd['SK_ID'] == i]['RES'].value_counts()).shape[0] > 1):
            print('1\n',file=file,flush=True)
        else:
            print('0\n',file=file,flush=True)

# %%
ans = pd.read_csv("ans.csv",sep=";")

# %%
ans.shape
# Out:
# (5220, 1)
